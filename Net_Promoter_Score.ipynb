# %% [markdown]
# <a href="https://colab.research.google.com/github/cperezgarcia/Patentes/blob/main/Net_Promoter_Score.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import plotly.express as px
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import matplotlib.pyplot as plt
import datetime as dt
# Out:
# /usr/local/lib/python3.7/dist-packages/distributed/config.py:20: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   defaults = yaml.load(f)

# %%
df = pd.read_csv("/data_model_2.csv")
df.head()
# Out:
#    ID Cliente  Año de ingreso Clasificación               CSM  \
# 0         230            2020             A  Victor Fernandez
# 1         258            2020             A    Felipe Menares
# 2         268            2021             A      Anibal Lopez
# 3         186            2019             A      Anibal Lopez
# 4         129            2018             A      Anibal Lopez
#
#    Estaciones revisadas 2021  Estaciones revisadas 2022  Estado  IF  IS  ISP  \
# 0                         21                         23  Activo  13   0    0
# 1                          6                          8  Activo   8  10    0
# 2                          3                          6  Activo   0   0    0
# 3                          4                          0  Activo   4   8    0
# 4                          4                          5  Activo   0  13    0
#
#    ...  Revisiones 2022  Total alarmas  Total informes  Total ingresos  \
# ...

# %%
df_copy= df.copy()
df_copy = pd.get_dummies(df_copy, columns = ['Estado'])

# %%
#!pip install sweetviz
#import sweetviz

# %%
df_copy=df_copy.drop(columns=["ID Cliente","Total Servicios.1","Estado_Inactivo"])
#my_report  = sweetviz.analyze(df_copy, target_feat='Estado_Activo')
#my_report.show_html('FinalReport.html')

# %%
# !pip install pycaret[full]
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
#!pip uninstall imgaug && pip uninstall albumentations && pip install git+https://github.com/aleju/imgaug.git
#!pip install pycaret==2.3.10 markupsafe==2.0.1 pyyaml==5.4.1 -qq
#import jinja2
from pycaret.classification import *

# %%
df_copy.dtypes

# %%
setup(df_copy,target='Estado_Activo', categorical_features=["Clasificación", "CSM","KAM", ],
      numeric_features=["Año de ingreso","Estaciones revisadas 2021","Estaciones revisadas 2022","IF","IS","ISP","IST","IW","IWell","IWP","Retrabajos 2021","Retrabajos 2022", "Revisiones 2021", "Revisiones 2022", "Total informes", "Total Servicios","Usuarios", "visitas 2021", "visitas 2022"])
# Out:
# IntProgress(value=0, description='Processing: ', max=3)
#
#
# Initiated  . . . . . . . . . . . . . . . . . .            09:14:49
# Status     . . . . . . . . . . . . . . . . . .  Preprocessing Data
# Text(value="Following data types have been inferred automatically, if they are correct press enter to continue…
#                              Data Type
# Año de ingreso                 Numeric
# Clasificación              Categorical
# CSM                        Categorical
# Estaciones revisadas 2021      Numeric
# Estaciones revisadas 2022      Numeric
# IF                             Numeric
# IS                             Numeric
# ISP                            Numeric
# IST                            Numeric
# IW                             Numeric
# IWell                          Numeric
# IWP                            Numeric
# KAM                        Categorical
# login 2021 diciembre           Numeric
# login 2022 abril               Numeric
# ...

# %%
best = compare_models()
